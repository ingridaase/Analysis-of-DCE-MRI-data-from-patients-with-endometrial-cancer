# %%
# %matplotlib widget

# %%
import math
import pandas as pd
import numpy as np
import scipy.ndimage
from scipy.optimize import curve_fit
import skimage
import skimage.measure
import matplotlib.pyplot as plt
from imagedata.series import Series

# %%
dce_path = 'H:/data/master endometrial data/135/dce'
mask_path = 'H:/data/master endometrial data/135/mask'

# %%
dce = Series(dce_path, 'time')
mask = Series(mask_path, 'time')

# %%
#Funker foreløpig ikke på helse-vest maskinen
#from mcflirt import * 
#dce_out = mcflirt(dce, mask)

# %%
experiment = {
    'dce': Series(dce, 'time'),
    'number_baseline': 5  # Length of baseline
}

# %%
#Plot function 
def show(signal, ax=None, show=False, label=None, color=None):
    if ax is None:
        fig, ax = plt.subplots(1)
        show = True
    ax.plot(signal, label=label, color=color)
    if label is not None:
        ax.legend(loc='upper right')
    if show:
        plt.show()

# %%
def relative_concentration_map(im, baseline, k, option):
    print('This is computing {} signal concentration map'.format(
        option.upper())
    )

    relim = np.zeros_like(im, dtype=np.float64)
    im0 = np.mean(im[:baseline], axis=0)
    for i in range(im.shape[0]):
        if option.upper().strip() == 'ABS':
            relim[i] = k * (im[i] - im0)
        elif option.upper().strip() == 'REL':
            relim[i] = k * (im[i] - im0) / im0
    relim[relim < 0] = 0
    return Series(relim, 'time', template=im, geometry=im)

# %%
# Show first volume of DCE
experiment['dce'][0].show(level=50, window=100)

# %%
# Relative concentration
k = 1
dce_rel = relative_concentration_map(experiment['dce'], experiment['number_baseline'], k, 'abs')
dce_rel.shape
# Out:
# This is computing ABS signal concentration map
# (160, 12, 256, 256)

# %%
#Plot relative concentration
dce_rel[10].show(level=10, window=20)

# %% [markdown]
# ### 1st step: select 1% of brightest voxel in first 25 timesteps

# %%
def select_brightest_voxels(dce, timesteps, percentile):
    assert timesteps>0 and timesteps<len(dce), "Timesteps {} out of range".format(timesteps)
    assert 0 < percentile < 100, "Percentile {} out of range".format(percentile)
    dce_sum = (np.sum(dce[:timesteps], axis=0, keepdims=True)/float(timesteps))[0]
    dce_pct = np.percentile(dce_sum, 100-percentile)
    brightest_voxels = dce_sum > dce_pct
    #dce_rgb = dce_sum.to_rgb()
    #dce_rgb[brightest_voxels] = (0xff, 0xff, 0)
    return brightest_voxels

# %%
brightest_voxels = select_brightest_voxels(dce_rel, timesteps=20, percentile=1)
print('Portion of brightest voxels: {:.1f}%'.format(100*brightest_voxels.sum() / dce_rel[0].size))
# Show t=20, slice=5 of dce_rel and brightest_voxels
dce_rel[25,5].show(brightest_voxels[5])
# Out:
# Portion of brightest voxels: 1.0%

# %%
print(dce_rel.shape)
# Out:
# (160, 12, 256, 256)

# %% [markdown]
# ### 2nd step: binary opening

# %%
def select_binary_opening(voxels):
    # morphological operation of a binary opening
    return scipy.ndimage.binary_opening(voxels)

# %%
binary_opening = select_binary_opening(brightest_voxels)
print(binary_opening.shape)
print('Portion of binary opening voxels: {:.1f}%'.format(100*binary_opening.sum() / dce_rel[0].size))
fig, ax = plt.subplots(1)
plt.imshow(binary_opening[5])
# Out:
# (12, 256, 256)
# Portion of binary opening voxels: 0.4%

# %%
print(binary_opening.shape)
# Out:
# (12, 256, 256)

# %% [markdown]
# ### 3rd step: find timestep with the most peak values

# %%
def find_most_peak_values(dce, mask, timesteps, ax1=None, ax2=None):
    ## Timestep of peak value for every voxel in mask
    peak_values = np.array(np.argmax(dce[:timesteps, mask], axis=0))
    print('find_most_peak_values: peak_values type {}, nonzero {}, size {}, shape {}'.format(type(peak_values), np.count_nonzero(peak_values), peak_values.size, peak_values.shape))

    # Include voxels in first part of timeline only, do not include boundaries
    one_part = timesteps
    first_part_1 = np.bitwise_and(0 < peak_values, peak_values < one_part)
    
    first_part = np.zeros_like(dce[0], dtype=bool)
    first_part[mask] = first_part_1
    print('find_most_peak_values: first_part', first_part.shape, first_part.sum())
    
    # Select most frequent peak timestep
    peak_value = np.argmax(dce[:timesteps, first_part], axis=0)
    hist, edges = np.histogram(peak_value, bins=one_part)
    max_timestep = np.argmax(hist)
    
    print('find_most_peak_values: Max timestep: {}'.format(max_timestep))

    if ax1 is not None:
        #plt.subplot(221)
        ax1.plot(peak_values)
    if ax2 is not None:
        #plt.subplot(222)
        ax2.plot(hist)
        ax2.axvline(max_timestep, color='r')
    
    if max_timestep == 0 or max_timestep >= timesteps-1:
        # Do not include boundaries
        return None, None
    else:
        # Retain found timestep only
        retain_voxels = np.zeros_like(dce[0])
        retain_voxels[mask] = dce[max_timestep, mask]
        return max_timestep, retain_voxels

# %%
fig, axs = plt.subplots(2, 2)
max_timestep, retain_voxels = find_most_peak_values(dce_rel, binary_opening, timesteps=22, ax1=axs[0, 0], ax2=axs[0, 1])
if max_timestep is None:
    max_timestep, retain_voxels = find_most_peak_values(dce_rel, binary_opening, timesteps=30, ax1=axs[0, 0], ax2=axs[0, 1])
print('Portion of retained voxels 1: {:.1f}%'.format(100*np.count_nonzero(retain_voxels) / dce_rel[0].size))
axs[1,0].imshow(retain_voxels[5])
plt.show()
# Out:
# find_most_peak_values: peak_values type <class 'numpy.ndarray'>, nonzero 2725, size 2914, shape (2914,)
# find_most_peak_values: first_part (12, 256, 256) 2725
# find_most_peak_values: Max timestep: 19
# Portion of retained voxels 1: 0.3%

# %% [markdown]
# ### 4th step: blob and tube filter

# %%
# From binary_opening mask
# Connected component analysis to find objects in the mask, connectivity 18
connectivity = 18

# Skip for now - is intended to locate tubular objects

# %%
# For each found object

# %%
from skimage.filters import meijering, sato, frangi, hessian

fig, ax = plt.subplots(ncols=5) 

image = np.asarray(dce_rel[0:20].mean(axis=0), dtype='float')

ax[0].imshow(image[5], cmap=plt.cm.gray)
ax[0].set_title('Original')

#Frangi vesselness filter 
ax[1].imshow(frangi(image[5]), cmap=plt.cm.gray)
ax[1].set_title('Frangi')

#Hybrid Hessian filter
ax[2].imshow(hessian(image[5]), cmap=plt.cm.gray)
ax[2].set_title('Hessian')

#Sato tubeness filter
ax[3].imshow(sato(image[5]), cmap=plt.cm.gray)
ax[3].set_title('Sato')

#Meijering neuriteness filter
ax[4].imshow(meijering(image[5]), cmap=plt.cm.gray) 
ax[4].set_title('Meijering')

for a in ax: 
    a.axis("off")

plt.tight_layout()
# Out:
# Previously, hessian implicitly used 'constant' as the border mode when dealing with the edge of the array. The new behavior is 'reflect'. To recover the old behavior, use mode='constant'. To avoid this warning, please explicitly set the mode.
# Previously, sato implicitly used 'constant' as the border mode when dealing with the edge of the array. The new behavior is 'reflect'. To recover the old behavior, use mode='constant'. To avoid this warning, please explicitly set the mode.

# %% [markdown]
# ### 5th step: find timestep with most peak values and compare to result of step 3

# %% [markdown]
# ### 6th step: fit Parker population AIF

# %%
print('binary_opening', binary_opening.shape, binary_opening.dtype)
label_im, num_labels = skimage.measure.label(binary_opening, return_num=True, connectivity=3)

regions = skimage.measure.regionprops(label_im)
print('label_im', label_im.shape, label_im.dtype, num_labels)
print('Regions: {}'.format(len(regions)))
fig, ax = plt.subplots(1, 1)
ax.imshow(label_im[5])
plt.show()
# Out:
# binary_opening (12, 256, 256) bool
# label_im (12, 256, 256) int32 31
# Regions: 31

# %%
print(regions)
# Out:
# [<skimage.measure._regionprops.RegionProperties object at 0x0000027BD8394E80>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BBF801B20>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD79AFC10>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC9669100>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC9669040>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC9669850>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC9669B20>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC9669250>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC96693D0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD2397610>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD23974C0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD2397490>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD2397370>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD6244760>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BC6E05B50>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BD78A43A0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E880>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E7F0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E5B0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8EB20>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E610>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E640>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8EEB0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8EE20>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E430>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E760>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E5E0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8EBE0>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8E670>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BCFB8EC40>, <skimage.measure._regionprops.RegionProperties object at 0x0000027BBF864EE0>]

# %%
properties = ['area','convex_area','bbox_area', 'extent',
              'mean_intensity', 'solidity', #'eccentricity',
              #'orientation'
    ]
df = pd.DataFrame(skimage.measure.regionprops_table(label_im, binary_opening, 
             properties=properties))
df
# Out:
#     area  convex_area  bbox_area    extent  mean_intensity  solidity
# 0      7            7         27  0.259259             1.0  1.000000
# 1      7            7         27  0.259259             1.0  1.000000
# 2     12           12         36  0.333333             1.0  1.000000
# 3     24           24         60  0.400000             1.0  1.000000
# 4     32           32        108  0.296296             1.0  1.000000
# 5     20           20         60  0.333333             1.0  1.000000
# 6    951         2132       9000  0.105667             1.0  0.446060
# 7    238          386       1188  0.200337             1.0  0.616580
# 8    161          207        605  0.266116             1.0  0.777778
# 9     62           78        192  0.322917             1.0  0.794872
# 10   539         1142       3276  0.164530             1.0  0.471979
# 11   101          159        504  0.200397             1.0  0.635220
# 12   230          429       1078  0.213358             1.0  0.536131
# 13    70           77        245  0.285714             1.0  0.909091
# 14     7            7         27  0.259259             1.0  1.000000
# 15    52           54        180  0.288889             1.0  0.962963
# 16     7            7         27  0.259259             1.0  1.000000
# 17    26           30         80  0.325000             1.0  0.866667
# 18    54           77        528  0.102273             1.0  0.701299
# 19    12           12         36  0.333333             1.0  1.000000
# 20    12           12         36  0.333333             1.0  1.000000
# 21     7            7         27  0.259259             1.0  1.000000
# 22     7            7         27  0.259259             1.0  1.000000
# 23     7            7         27  0.259259             1.0  1.000000
# 24    12           12         36  0.333333             1.0  1.000000
# 25   203          312       1040  0.195192             1.0  0.650641
# 26     7            7         27  0.259259             1.0  1.000000
# 27    16           16         48  0.333333             1.0  1.000000
# 28    17           17         45  0.377778             1.0  1.000000
# 29     7            7         27  0.259259             1.0  1.000000
# 30     7            7         27  0.259259             1.0  1.000000

# %%
area_threshold = 100
df[df['area'] > area_threshold]
# Out:
#     area  convex_area  bbox_area    extent  mean_intensity  solidity
# 6    951         2132       9000  0.105667             1.0  0.446060
# 7    238          386       1188  0.200337             1.0  0.616580
# 8    161          207        605  0.266116             1.0  0.777778
# 10   539         1142       3276  0.164530             1.0  0.471979
# 11   101          159        504  0.200397             1.0  0.635220
# 12   230          429       1078  0.213358             1.0  0.536131
# 25   203          312       1040  0.195192             1.0  0.650641

# %%
def find_promising_objects(regions):
    masks = []
    bbox = []
    list_of_index = []
    for num, x in enumerate(regions):
        area = x.area
        convex_area = x.convex_area
        if (num!=0 and area>10 and (convex_area/area <1.1) and (convex_area/area >0.90)):
        #if num!=0 and (area>area_threshold):
            masks.append(regions[num].convex_image)
            bbox.append(regions[num].bbox)   
            list_of_index.append(num)
    return masks, bbox, list_of_index

# %%
masks, bbox, list_of_index = find_promising_objects(regions)
count = len(masks)
print(count)
print(int(count//3))
painting = dce_rel[0].to_rgb()
print('Painting:', painting.shape, painting.dtype)
fig, ax = plt.subplots(3, int(count//3), figsize=(15,8))
for axis, box, mask in zip(ax.flatten(), bbox, masks):
    red  =  painting[...,0][box[0]:box[3], box[1]:box[4], box[2]:box[5]] * mask
    green = painting[...,1][box[0]:box[3], box[1]:box[4], box[2]:box[5]] * mask
    blue  = painting[...,2][box[0]:box[3], box[1]:box[4], box[2]:box[5]] * mask
    mid = len(red)//2
    image = Series(np.zeros(red.shape+(3,), dtype=red.dtype))
    image[..., 0] = red
    image[..., 1] = green
    image[..., 2] = blue
    axis.imshow(image[mid]*10)
plt.show()
# Out:
# 10
# 3
# Painting: (12, 256, 256, 3) uint8

# %%
rgb_mask = np.zeros_like(label_im)
for x in list_of_index:
    rgb_mask += (label_im==x+1).astype(int)
red  =  painting[...,0] * rgb_mask
green = painting[...,1] * rgb_mask
blue  = painting[...,2] * rgb_mask
image = dce_rel[0].to_rgb()
print('image', image.shape, image.dtype)
image[..., 0] = red
image[..., 1] = green
image[..., 2] = blue
plt.imshow(image[6]*10)
plt.show()
# Out:
# image (12, 256, 256, 3) uint8

# %%
time_course = {}
print(list_of_index)
fig, ax = plt.subplots(len(list_of_index), figsize=(15,8))
for i, x in enumerate(list_of_index):
    rgb_mask = (label_im==x+1).astype(int)
    time_course[x] = np.sum(dce_rel, axis=(1,2,3), where=label_im==x+1)/np.count_nonzero(label_im==x+1)
    show(time_course[x], ax=ax[i], label=x)
plt.show()
# Out:
# [2, 3, 4, 5, 15, 19, 20, 24, 27, 28]

# %%
def parker(x, N, t):
    # print('parker: x {} '.format(x.shape))
    A1, A2, T1, T2, sigma1, sigma2, alpha, beta, s, tau = x
    # print(A1,A2,T1,T2,sigma1,sigma2,alpha,beta,s,tau)

    term = np.zeros((3, N))
    term[0] = A1 / sigma1 / math.sqrt(2 * math.pi) * np.exp(-((t - T1) ** 2) / 2 / (sigma1 ** 2))
    term[1] = A2 / sigma2 / math.sqrt(2 * math.pi) * np.exp(-((t - T2) ** 2) / 2 / (sigma2 ** 2))
    term[2] = alpha * np.exp(-beta * t) / (1 + np.exp(-s * (t - tau)))

    # aif = np.sum(term, axis=0) * scaling
    aif = np.sum(term, axis=0)
    # return aif, term[0], term[1], alpha*np.exp(-beta*t), 1/(np.exp(-s*(t-tau)))
    return aif

def parker_cost_function(x, t, y):
    return parker(x, y.shape[0], t) - y

def estimate_parkers_model(measured, timeline):
    # timeline in minutes
    norm_factor = max(measured)
    y = measured / norm_factor

    A1 = 0.809
    A2 = 0.33
    T1 = 0.17046
    T2 = 0.365
    sigma1 = 0.0563
    sigma2 = 0.132
    alpha = 1.050
    beta = 0.1685
    s = 38.078
    tau = 0.483

    x0 = np.array((A1, A2, T1, T2, sigma1, sigma2, alpha, beta, s, tau))
    lb = np.array((0, 0, 0.1, 0.2, 1e-9, 1e-9, 1e-3, 0, 0, 0))
    ub = np.array((5, 5, 2, 2, 0.5, 0.7, 5.0, 1.17, 50, 1.5))
    xs = np.array((1, 1, 1, 1, 20, 10, 1, 1, 0.05, 1))
    result = scipy.optimize.least_squares(parker_cost_function, x0, bounds=(lb, ub), x_scale=xs,
                                    args=(timeline, y), verbose=1, ftol=1e-3, xtol=1e-3, gtol=1e-3)
    print('estimate_parkers_model: result.cost: {}'.format(result.cost))
    print('estimate_parkers_model: A1    : {:6.3f} {:6.3f}'.format(x0[0], result.x[0]))
    print('estimate_parkers_model: A2    : {:6.3f} {:6.3f}'.format(x0[1], result.x[1]))
    print('estimate_parkers_model: T1    : {:6.3f} {:6.3f}'.format(x0[2], result.x[2]))
    print('estimate_parkers_model: T2    : {:6.3f} {:6.3f}'.format(x0[3], result.x[3]))
    print('estimate_parkers_model: sigma1: {:6.3f} {:6.3f}'.format(x0[4], result.x[4]))
    print('estimate_parkers_model: sigma2: {:6.3f} {:6.3f}'.format(x0[5], result.x[5]))
    print('estimate_parkers_model: alpha : {:6.3f} {:6.3f}'.format(x0[6], result.x[6]))
    print('estimate_parkers_model: beta  : {:6.3f} {:6.3f}'.format(x0[7], result.x[7]))
    print('estimate_parkers_model: s     : {:6.3f} {:6.3f}'.format(x0[8], result.x[8]))
    print('estimate_parkers_model: tau   : {:6.3f} {:6.3f}'.format(x0[9], result.x[9]))
    return result

# %%
# Fit Parker population AIF
fit = {}
df['cost'] = math.nan
df['T1'] = math.nan
df['T2'] = math.nan
fig, ax = plt.subplots(len(list_of_index), figsize=(15,8))
for i, x in enumerate(list_of_index):
    print('Fit time course {}:'.format(x))
    half = len(dce_rel.timeline)//2
    # solution = estimate_parkers_model(time_course[x], dce_rel.timeline/60)
    solution = estimate_parkers_model(time_course[x][:half], dce_rel.timeline[:half]/60)
    print('solution', solution.cost, solution.success)
    fit[x] = solution
    show(time_course[x], ax=ax[i], label=x)
    t_auc = np.sum(time_course[x][:half])
    p = parker(fit[x].x, half, fit[x].fun.timeline[:half]/60)
    p_auc = np.sum(p)
    show(p*t_auc/p_auc,ax=ax[i], label=x)
    df.at[x, 'cost'] = solution.cost
    df.at[x, 'T1'] = solution.x[2]
    df.at[x, 'T2'] = solution.x[3]
plt.show()
# Out:
# Fit time course 2:
# `ftol` termination condition is satisfied.
# Function evaluations 11, initial cost 5.3885e+01, final cost 2.0003e+00, first-order optimality 1.93e-03.
# estimate_parkers_model: result.cost: 2.0003352446854405
# estimate_parkers_model: A1    :  0.809  0.159
# estimate_parkers_model: A2    :  0.330  0.081
# estimate_parkers_model: T1    :  0.170  0.303
# estimate_parkers_model: T2    :  0.365  0.599
# estimate_parkers_model: sigma1:  0.056  0.086
# estimate_parkers_model: sigma2:  0.132  0.061
# estimate_parkers_model: alpha :  1.050  0.327
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078 48.460
# estimate_parkers_model: tau   :  0.483  0.887
# solution 2.0003352446854405 True
# Fit time course 3:
# `ftol` termination condition is satisfied.
# Function evaluations 9, initial cost 5.4478e+01, final cost 2.5427e+00, first-order optimality 2.61e-02.
# estimate_parkers_model: result.cost: 2.5427480779365497
# estimate_parkers_model: A1    :  0.809  0.191
# estimate_parkers_model: A2    :  0.330  0.082
# estimate_parkers_model: T1    :  0.170  0.333
# estimate_parkers_model: T2    :  0.365  0.630
# estimate_parkers_model: sigma1:  0.056  0.086
# estimate_parkers_model: sigma2:  0.132  0.043
# estimate_parkers_model: alpha :  1.050  0.389
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078 41.007
# estimate_parkers_model: tau   :  0.483  0.947
# solution 2.5427480779365497 True
# Fit time course 4:
# `ftol` termination condition is satisfied.
# Function evaluations 16, initial cost 6.1428e+01, final cost 1.6056e+00, first-order optimality 7.74e-02.
# estimate_parkers_model: result.cost: 1.6056470868063961
# estimate_parkers_model: A1    :  0.809  0.053
# estimate_parkers_model: A2    :  0.330  0.001
# estimate_parkers_model: T1    :  0.170  0.383
# estimate_parkers_model: T2    :  0.365  0.211
# estimate_parkers_model: sigma1:  0.056  0.058
# estimate_parkers_model: sigma2:  0.132  0.007
# estimate_parkers_model: alpha :  1.050  0.451
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078  1.749
# estimate_parkers_model: tau   :  0.483  1.500
# solution 1.6056470868063961 True
# Fit time course 5:
# `ftol` termination condition is satisfied.
# Function evaluations 20, initial cost 6.1028e+01, final cost 2.0726e+00, first-order optimality 1.36e-02.
# estimate_parkers_model: result.cost: 2.0725542143847306
# estimate_parkers_model: A1    :  0.809  0.043
# estimate_parkers_model: A2    :  0.330  0.058
# estimate_parkers_model: T1    :  0.170  0.104
# estimate_parkers_model: T2    :  0.365  0.381
# estimate_parkers_model: sigma1:  0.056  0.219
# estimate_parkers_model: sigma2:  0.132  0.074
# estimate_parkers_model: alpha :  1.050  0.452
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078  1.589
# estimate_parkers_model: tau   :  0.483  1.500
# solution 2.0725542143847306 True
# Fit time course 15:
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 5.1577e+01, final cost 9.2541e-01, first-order optimality 2.31e-03.
# estimate_parkers_model: result.cost: 0.925408000164305
# estimate_parkers_model: A1    :  0.809  0.061
# estimate_parkers_model: A2    :  0.330  0.045
# estimate_parkers_model: T1    :  0.170  0.264
# estimate_parkers_model: T2    :  0.365  0.537
# estimate_parkers_model: sigma1:  0.056  0.042
# estimate_parkers_model: sigma2:  0.132  0.038
# estimate_parkers_model: alpha :  1.050  0.677
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078  9.869
# estimate_parkers_model: tau   :  0.483  0.884
# solution 0.925408000164305 True
# Fit time course 19:
# `ftol` termination condition is satisfied.
# Function evaluations 31, initial cost 5.4034e+01, final cost 6.9358e-02, first-order optimality 8.64e-02.
# estimate_parkers_model: result.cost: 0.0693584701183003
# estimate_parkers_model: A1    :  0.809  0.043
# estimate_parkers_model: A2    :  0.330  0.108
# estimate_parkers_model: T1    :  0.170  1.022
# estimate_parkers_model: T2    :  0.365  0.785
# estimate_parkers_model: sigma1:  0.056  0.137
# estimate_parkers_model: sigma2:  0.132  0.067
# estimate_parkers_model: alpha :  1.050  0.931
# estimate_parkers_model: beta  :  0.169  0.014
# estimate_parkers_model: s     : 38.078 16.581
# estimate_parkers_model: tau   :  0.483  0.917
# solution 0.0693584701183003 True
# Fit time course 20:
# `xtol` termination condition is satisfied.
# Function evaluations 12, initial cost 5.3685e+01, final cost 4.5616e-02, first-order optimality 3.30e-01.
# estimate_parkers_model: result.cost: 0.045615551197361756
# estimate_parkers_model: A1    :  0.809  0.026
# estimate_parkers_model: A2    :  0.330  0.145
# estimate_parkers_model: T1    :  0.170  0.105
# estimate_parkers_model: T2    :  0.365  0.805
# estimate_parkers_model: sigma1:  0.056  0.429
# estimate_parkers_model: sigma2:  0.132  0.078
# estimate_parkers_model: alpha :  1.050  0.969
# estimate_parkers_model: beta  :  0.169  0.030
# estimate_parkers_model: s     : 38.078 26.508
# estimate_parkers_model: tau   :  0.483  0.925
# solution 0.045615551197361756 True
# Fit time course 24:
# `gtol` termination condition is satisfied.
# Function evaluations 17, initial cost 5.2869e+01, final cost 7.9910e-02, first-order optimality 9.78e-04.
# estimate_parkers_model: result.cost: 0.07991003212275039
# estimate_parkers_model: A1    :  0.809  0.017
# estimate_parkers_model: A2    :  0.330  0.171
# estimate_parkers_model: T1    :  0.170  0.100
# estimate_parkers_model: T2    :  0.365  0.790
# estimate_parkers_model: sigma1:  0.056  0.222
# estimate_parkers_model: sigma2:  0.132  0.069
# estimate_parkers_model: alpha :  1.050  0.819
# estimate_parkers_model: beta  :  0.169  0.035
# estimate_parkers_model: s     : 38.078 20.708
# estimate_parkers_model: tau   :  0.483  0.898
# solution 0.07991003212275039 True
# Fit time course 27:
# `ftol` termination condition is satisfied.
# Function evaluations 15, initial cost 5.3854e+01, final cost 5.4454e-02, first-order optimality 8.05e-03.
# estimate_parkers_model: result.cost: 0.054454498753679324
# estimate_parkers_model: A1    :  0.809  0.019
# estimate_parkers_model: A2    :  0.330  0.099
# estimate_parkers_model: T1    :  0.170  0.100
# estimate_parkers_model: T2    :  0.365  0.775
# estimate_parkers_model: sigma1:  0.056  0.425
# estimate_parkers_model: sigma2:  0.132  0.058
# estimate_parkers_model: alpha :  1.050  0.985
# estimate_parkers_model: beta  :  0.169  0.042
# estimate_parkers_model: s     : 38.078 19.438
# estimate_parkers_model: tau   :  0.483  0.873
# solution 0.054454498753679324 True
# Fit time course 28:
# `ftol` termination condition is satisfied.
# Function evaluations 13, initial cost 5.3681e+01, final cost 1.2224e-01, first-order optimality 3.67e-02.
# estimate_parkers_model: result.cost: 0.12223782464629096
# estimate_parkers_model: A1    :  0.809  0.041
# estimate_parkers_model: A2    :  0.330  0.107
# estimate_parkers_model: T1    :  0.170  0.104
# estimate_parkers_model: T2    :  0.365  0.777
# estimate_parkers_model: sigma1:  0.056  0.286
# estimate_parkers_model: sigma2:  0.132  0.059
# estimate_parkers_model: alpha :  1.050  0.909
# estimate_parkers_model: beta  :  0.169  0.000
# estimate_parkers_model: s     : 38.078 12.574
# estimate_parkers_model: tau   :  0.483  0.866
# solution 0.12223782464629096 True

# %%
test_timecourses = []# 11, 120]
if len(test_timecourses) > 0:
    fig, ax = plt.subplots(len(test_timecourses), figsize=(15,8))
    for i, x in enumerate(test_timecourses):
        show(time_course[x], ax=ax[i], label=x)
        t_auc = np.sum(time_course[x][:half])
        p = parker(fit[x].x, half, fit[x].fun.timeline[:half]/60)
        p_auc = np.sum(p)
        show(p*t_auc/p_auc,ax=ax[i], label=x)
    plt.show()

# %%
df[df['cost'] > 1e-3]
# Out:
#     area  convex_area  bbox_area    extent  mean_intensity  solidity  \
# 2     12           12         36  0.333333             1.0  1.000000
# 3     24           24         60  0.400000             1.0  1.000000
# 4     32           32        108  0.296296             1.0  1.000000
# 5     20           20         60  0.333333             1.0  1.000000
# 15    52           54        180  0.288889             1.0  0.962963
# 19    12           12         36  0.333333             1.0  1.000000
# 20    12           12         36  0.333333             1.0  1.000000
# 24    12           12         36  0.333333             1.0  1.000000
# 27    16           16         48  0.333333             1.0  1.000000
# 28    17           17         45  0.377778             1.0  1.000000
#
#         cost        T1        T2
# 2   2.000335  0.302759  0.598822
# 3   2.542748  0.332737  0.630264
# 4   1.605647  0.383393  0.210513
# 5   2.072554  0.103780  0.381432
# 15  0.925408  0.263878  0.537239
# 19  0.069358  1.022078  0.784664
# 20  0.045616  0.104681  0.805268
# 24  0.079910  0.100001  0.790023
# 27  0.054454  0.100002  0.774568
# 28  0.122238  0.104126  0.777074

# %%
i = df['cost'].idxmin()
print(df.iloc[[i]])
best_fit = i
# Out:
#     area  convex_area  bbox_area    extent  mean_intensity  solidity  \
# 20    12           12         36  0.333333             1.0       1.0
#
#         cost        T1        T2
# 20  0.045616  0.104681  0.805268

# %% [markdown]
# ### 7th step: erosion and dilation

# %%
square = np.array([[1,1,1],
                   [1,1,1],
                   [1,1,1]])

def multi_dil(im, num, element=square):
    for i in range(num):
        im = skimage.morphology.dilation(im, element)
    return im
def multi_ero(im, num, element=square):
    for i in range(num):
        im = skimage.morphology.erosion(im, element)
    return im

# %%
mask = (label_im==best_fit+1).astype(int)
print(type(mask), mask.shape, mask.dtype, mask.max())

#multi_dilated = multi_dil(mask, num=3, element=skimage.morphology.cube(3))
#multi_eroded = multi_ero(multi_dilated, num=3, element=skimage.morphology.cube(3))
multi_eroded = multi_ero(mask, num=1, element=skimage.morphology.cube(3))
multi_dilated = multi_dil(multi_eroded, num=1, element=skimage.morphology.cube(3))
print('multi_eroded', multi_eroded.max())
print('multi_dilated', multi_dilated.max())
plt.subplot(221)
plt.imshow(mask[9]*100)
plt.subplot(222)
plt.imshow(multi_eroded[9]*100)
plt.subplot(223)
plt.imshow(multi_dilated[9]*100)
# mask = multi_eroded
plt.tight_layout()
plt.show()
# Out:
# <class 'numpy.ndarray'> (12, 256, 256) int32 1
# multi_eroded 0
# multi_dilated 0

# %%
tc = np.sum(dce_rel, axis=(1,2,3), where=multi_dilated==True)/np.count_nonzero(multi_dilated)
solution = estimate_parkers_model(tc[:half], dce_rel.timeline[:half]/60)
print('Cost after dilation: {:.4f}, before dilation {:.4f}'.format(solution.cost, df['cost'].min()))
if solution.cost < df['cost'].min():
    print('Selecting dilated mask')
    mask = multi_dilated
else:
    print('Keeping mask')
# Out:
# invalid value encountered in true_divide
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15380/3470204493.py in <module>
#       1 tc = np.sum(dce_rel, axis=(1,2,3), where=multi_dilated==True)/np.count_nonzero(multi_dilated)
# ----> 2 solution = estimate_parkers_model(tc[:half], dce_rel.timeline[:half]/60)
#       3 print('Cost after dilation: {:.4f}, before dilation {:.4f}'.format(solution.cost, df['cost'].min()))
#       4 if solution.cost < df['cost'].min():
#       5     print('Selecting dilated mask')
#
# ~\AppData\Local\Temp/ipykernel_15380/3424487106.py in estimate_parkers_model(measured, timeline)
#      37     ub = np.array((5, 5, 2, 2, 0.5, 0.7, 5.0, 1.17, 50, 1.5))
#      38     xs = np.array((1, 1, 1, 1, 20, 10, 1, 1, 0.05, 1))
# ---> 39     result = scipy.optimize.least_squares(parker_cost_function, x0, bounds=(lb, ub), x_scale=xs,
#      40                                     args=(timeline, y), verbose=1, ftol=1e-3, xtol=1e-3, gtol=1e-3)
#      41     print('estimate_parkers_model: result.cost: {}'.format(result.cost))
#
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\optimize\_lsq\least_squares.py in least_squares(fun, x0, jac, bounds, method, ftol, xtol, gtol, x_scale, loss, f_scale, diff_step, tr_solver, tr_options, jac_sparsity, max_nfev, verbose, args, kwargs)
#     825
#     826     if not np.all(np.isfinite(f0)):
# --> 827         raise ValueError("Residuals are not finite in the initial point.")
#     828
#     829     n = x0.size
#
# ValueError: Residuals are not finite in the initial point.

# %% [markdown]
# ### 8th step: region growing

# %%
def find_brightest_voxel(dce):
    assert dce.ndim == 3, "dce shall be 3-dim, is {}".format(dce.shape)
    _w = np.where(dce == np.max(dce))
    return (int(_w[0]),), (int(_w[1]),), (int(_w[2]),)

# %%
print('mask', mask.shape, mask.dtype, mask.max(), np.count_nonzero(mask))
_sum = np.sum(dce_rel[:10] * mask, axis=0)/10.
seed_point = find_brightest_voxel(_sum)
print('seed', seed_point)
print('_sum', _sum.shape, _sum.dtype)

_sum_in_mask = np.extract(mask==1, _sum)
# print('_sum_in_mask', _sum_in_mask.shape, np.count_nonzero(mask))

brightest_intensity = float(_sum[seed_point])
_quantile = np.quantile(_sum_in_mask, 0.8)
_sum_in_quantile = np.extract(_sum_in_mask>_quantile, _sum_in_mask)
plt.subplots(1, 1)
plt.hist(_sum_in_quantile)
print('quantile', _quantile)
_mean = np.mean(_sum_in_mask, where=_sum_in_mask>_quantile)
_std = np.std(_sum_in_mask, where=_sum_in_mask>_quantile)
threshold = _mean - _std
print('brightest', brightest_intensity, 'mean', _mean, 'std', _std, 'threshold', threshold)
plt.show()
# Out:
# mask (12, 256, 256) int32 1 12
# seed ((6,), (119,), (46,))
# _sum (12, 256, 256) float64
# quantile 1.5719999999999998
# brightest 1.979999999999999 mean 1.7799999999999994 std 0.15577761927397193 threshold 1.6242223807260274

# %%
# Flood fill region growing from seed_point with threshold
print('grow: threshold', threshold)
tolerance=brightest_intensity-threshold
print('grow: tolerance', tolerance)
print('grow: seed_point', seed_point)
seed_point=(seed_point[0][0], seed_point[1][0], seed_point[2][0])
print('grow: seed_point', seed_point)
m = skimage.morphology.flood(_sum, seed_point, tolerance=tolerance)
print('grow: m', m.shape, m.dtype, m.max(), np.count_nonzero(m))
# Out:
# grow: threshold 1.6242223807260274
# grow: tolerance 0.35577761927397167
# grow: seed_point ((6,), (119,), (46,))
# grow: seed_point (6, 119, 46)
# grow: m (12, 256, 256) bool True 2

# %%
plt.subplots(1, 2)
plt.subplot(121)
plt.imshow(mask[5])
plt.subplot(122)
plt.imshow(m[5])

# %%
tc = np.sum(dce_rel, axis=(1,2,3), where=m==True)/np.count_nonzero(m)
solution = estimate_parkers_model(tc[:half], dce_rel.timeline[:half]/60)
print('Cost after region growing: {:.4f}, before region growing: {:.4f}'.format(solution.cost, df['cost'].min()))
if solution.cost < df['cost'].min():
    print('Selecting region grow mask')
    mask = m
else:
    print('Keeping mask')
# Out:
# `ftol` termination condition is satisfied.
# Function evaluations 12, initial cost 5.2784e+01, final cost 5.5826e-02, first-order optimality 3.50e-03.
# estimate_parkers_model: result.cost: 0.05582564671482135
# estimate_parkers_model: A1    :  0.809  0.023
# estimate_parkers_model: A2    :  0.330  0.155
# estimate_parkers_model: T1    :  0.170  0.372
# estimate_parkers_model: T2    :  0.365  0.817
# estimate_parkers_model: sigma1:  0.056  0.125
# estimate_parkers_model: sigma2:  0.132  0.086
# estimate_parkers_model: alpha :  1.050  0.998
# estimate_parkers_model: beta  :  0.169  0.059
# estimate_parkers_model: s     : 38.078 31.991
# estimate_parkers_model: tau   :  0.483  0.935
# Cost after region growing: 0.0558, before region growing: 0.0456
# Keeping mask

# %% [markdown]
# ### k-means clustering of time-courses

# %%
#print(best_fit, label_im.shape)
#mask = (label_im==best_fit+1).astype(int)
#    time_course[x] = np.sum(dce_rel, axis=(1,2,3), where=label_im==x+1)/np.count_nonzero(label_im==x+1)
plt.subplots(1, 1)
plt.imshow(mask[8])
timecourses = []
for s in range(dce_rel.shape[1]):
    for r in range(dce_rel.shape[2]):
        for c in range(dce_rel.shape[3]):
            if mask[s,r,c]:
                timecourses.append(dce_rel[:,s,r,c])
print(len(timecourses))
plt.show()
# Out:
# 12

# %%
from sklearn.cluster import KMeans
def kmeans_cluster(df, n_clusters=2):
    """k-means cluster a given data frame into a specified number of
    clusters.
    It will then return a copy of the original data frame with those
    clusters appended in a column named Cluster.

    https://www.districtdatalabs.com/data-exploration-with-python-2
    """

    model = KMeans(n_clusters=n_clusters, random_state=1)
    clusters = model.fit_predict(df)
    #cluster_results = df.copy()
    #cluster_results['Cluster'] = clusters
    #return cluster_results
    return clusters

# %%
def summarize_clustering(results):
    """Count the number of objects that fall into each cluster and
    calculate the cluster means for each feature.
    It is going to merge the counts and means into a single data frame
    and then return that summary to us.

    https://www.districtdatalabs.com/data-exploration-with-python-2
    """

    cluster_size = results.groupby(['Cluster']).size().reset_index()
    cluster_size.columns = ['Cluster', 'Count']
    cluster_means = results.groupby(['Cluster'], as_index=False).mean()
    cluster_summary = pd.merge(cluster_size, cluster_means, on='Cluster')
    return cluster_summary

# %%
cluster_results = kmeans_cluster(timecourses, 5)
number_of_clusters = cluster_results.max()+1
print(len(cluster_results), number_of_clusters)
hist, edges = np.histogram(cluster_results, range=(0,number_of_clusters), bins=number_of_clusters)
print(hist)
print(edges)
#cluster_summary = summarize_clustering(cluster_results)
#cluster_summary
# Out:
# 12 5
# [3 2 4 2 1]
# [0. 1. 2. 3. 4. 5.]

# %%
tc = {}
idx = {}
for x in range(number_of_clusters):
    tc[x] = np.empty([hist[x],dce_rel.shape[0]], dtype=dce_rel.dtype)
    print(x, tc[x].shape)
    idx[x] = 0
i = 0
cmask = np.zeros_like(dce_rel[0], dtype=int)
for s in range(dce_rel.shape[1]):
    for r in range(dce_rel.shape[2]):
        for c in range(dce_rel.shape[3]):
            if mask[s,r,c]:
                cluster = cluster_results[i]
                ind = idx[cluster]
                tc[cluster][ind,:] = dce_rel[:,s,r,c]
                cmask[s,r,c] = cluster+1
                idx[cluster] += 1
                i +=1
# Average clusters
tcc = {}
baseline = np.zeros(number_of_clusters)
fullline = np.zeros(number_of_clusters)
for x in range(number_of_clusters):
    assert idx[x] == hist[x], "idx {} disagree with hist {}".format(idx[x], hist[x])
    tcc[x] = np.sum(tc[x], axis=0)/tc[x].shape[0]
    b = experiment['number_baseline']
    baseline[x] = np.sum(tcc[x][:b])/b
    fullline[x] = np.sum(tcc[x])/len(tcc[x])
best_fit = np.argmin(fullline)
print(best_fit)
# Out:
# 0 (3, 160)
# 1 (2, 160)
# 2 (4, 160)
# 3 (2, 160)
# 4 (1, 160)
# 1

# %%
import matplotlib as mpl
cc = ['r', 'g', 'b', 'c', 'y']
cmap = mpl.colors.ListedColormap(cc)

# %%
# plt.imshow mask with cluster color
print(mask.dtype, mask.max())
plt.subplots(3, 3)
plt.subplot(331)
plt.imshow(cmask[1], cmap=cmap, alpha=mask[1]*1.0)
plt.subplot(332)
plt.imshow(cmask[2], cmap=cmap, alpha=mask[2]*1.0)
plt.subplot(333)
plt.imshow(cmask[3], cmap=cmap, alpha=mask[3]*1.0)
plt.subplot(334)
plt.imshow(cmask[4], cmap=cmap, alpha=mask[4]*1.0)
plt.subplot(335)
plt.imshow(cmask[5], cmap=cmap, alpha=mask[5]*1.0)
plt.subplot(336)
plt.imshow(cmask[6], cmap=cmap, alpha=mask[6]*1.0)
plt.subplot(337)
plt.imshow(cmask[7], cmap=cmap, alpha=mask[7]*1.0)
plt.subplot(338)
plt.imshow(cmask[8], cmap=cmap, alpha=mask[8]*1.0)
plt.subplot(339)
plt.imshow(cmask[9], cmap=cmap, alpha=mask[9]*1.0)
plt.show()
# Out:
# int32 1

# %%
plt.subplots(1, 1)
#plt.imshow(cmask[8], cmap=cmap, alpha=np.float64(mask[8]))
plt.imshow(cmask[5], cmap=cmap, alpha=mask[5]*1.0)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,8))
for x in range(number_of_clusters):
    if x == best_fit:
        show(tcc[x], ax=ax, label='{} *'.format(x), color=cc[x])
    else:
        show(tcc[x], ax=ax, label=x, color=cc[x])
plt.show()

# %% [markdown]
# ### Result

# %%
result = best_fit
aif = tcc[best_fit]
show(aif)

# %%
timeline = experiment['dce'].timeline

# %%
cp = aif/(1-0.42)

# %%
from runtofts_fun import *

patient_path = 'H:/data/master endometrial data/135/' #Path to patient 29 data
mask_path = os.path.join(patient_path, 'mask')
#vibe_path = os.path.join(patient_path, 'fl3d_vibe_tra_2mm_2min')
#aif_path = os.path.join(patient_path, 'AIF')

mask = Series(mask_path)

read_option = 'mask2dce'
#model_option = 'average'

#Read data 
MASK, DCE, timeline = readdata(mask, experiment['dce'], read_option)

#Subtract pre-contrast signal from signal
DCE = DCE.astype('float32')
S0 = np.mean(DCE[0:5,:,:,:], axis=0)
dynim = DCE.copy()
for k in range(len(timeline)):
    dynim[k,:,:,:] = DCE[k,:,:,:] - S0

#Finding mean concentration inside mask 
non_zero_in_mask = np.nonzero(MASK) #index of nonzero elements in mask image
in_mask_vals = dynim[:, non_zero_in_mask[0], non_zero_in_mask[1], non_zero_in_mask[2]]
C = np.asarray(np.mean(in_mask_vals, axis=1), dtype='float')
opt_params, C_tofts = run_tofts(timeline, C, cp)

# %%
print(opt_params)
# Out:
# {'Ktrans': 0.002651801360478651, 've': 0.30314637862672295, 'vp': 0.6477707718550962, 'kep': 0.008747593728453958}
